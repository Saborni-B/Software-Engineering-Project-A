# %% [markdown]
# Define lat and lon of Melboune in Point's coordinate
#
# ![Screenshot%202023-08-14%20145924.png](attachment:Screenshot%202023-08-14%20145924.png)

# %% [markdown]
# QA60 is a band that contains quality assessment information regarding cloud and atmospheric infomations
#
# cirrus cloud is a type of cloud that has thinner lyper than regular cloud.
#
# Bitmasks define different types of bits that represent different qualities and conditions of the image.
# in QA60 band bit 10 represents regular clouds and bit 11 represents cirrus cloud
#
# In the code, if a pixel contains cloud then the bit position would be set to 1.
# variable mask contains the pixel that has clouds and set it to 0 to mask out the image
#
# ![Screenshot%202023-08-14%20153551.png](attachment:Screenshot%202023-08-14%20153551.png)

# %% [markdown]
# Sentinel 2 has different types of bands. B4(Red), B3(Green), B2(Blue) is the RGB bands that can been seen naturally.
# minimum and maximum value represent how the colors would be streched in the image.

# %% [markdown]
# Full code:
#
# ![Screenshot%202023-08-14%20155538.png](attachment:Screenshot%202023-08-14%20155538.png)

# %% [markdown]
# Result:
#     ![Screenshot%202023-08-14%20155655.png](attachment:Screenshot%202023-08-14%20155655.png)
